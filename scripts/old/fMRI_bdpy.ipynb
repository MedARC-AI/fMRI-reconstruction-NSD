# %% [markdown]
# # Testing out h5 files
#
# The h5 files are downloaded from [here](https://github.com/KamitaniLab/DeepImageReconstruction/tree/master/data/fmri).
# Please place them in a folder called `data`.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
data_path = os.path.join(os.path.dirname(os.path.realpath("__file__")), "data")
h5_file = os.path.join(data_path, "sub-01_perceptionNaturalImageTest_original_VC.h5")

# %%
from bdpy import BData
from bdpy.fig import makefigure, box_off, draw_footnote, tile_images

# Create an empty BData instance
bdata = BData()

# Load BData from a file
bdata = BData(h5_file)

# %%
# Show 'key' and 'description' of metadata
bdata.show_metadata()
# Out:
# | Key         | Description          |
# |-------------|----------------------|
# | VoxelData   | 1 = VoxelData        |
# | Run         | 1 = Run              |
# | Block       | 1 = Block            |
# | Label       | 1 = Label            |
# | image_index | Label stimulus_index |
# | stimulus_id | Label stimulus_id    |
# | voxel_x     | Voxel x coordinate   |
# | voxel_y     | Voxel y coordinate   |
# | voxel_z     | Voxel z coordinate   |
# | ROI_V1      | 1 = ROI V1           |
# | ROI_V2      | 1 = ROI V2           |
# | ROI_V3      | 1 = ROI V3           |
# | ROI_V4      | 1 = ROI V4           |
# | ROI_LOC     | 1 = ROI LOC          |
# | ROI_FFA     | 1 = ROI FFA          |
# | ROI_PPA     | 1 = ROI PPA          |
# | ROI_LVC     | 1 = ROI LVC          |
# | ROI_HVC     | 1 = ROI HVC          |
# | ROI_VC      | 1 = ROI VC           |

# %%
#TODO: I have no idea how to read the voxels, documentation from BDPY seems non-existent.
#Below is the best I could do, feel free to improve.
voxel_x = bdata.select('voxel_x')
#TODO: Why is voxel_y empty?
voxel_y = bdata.select('voxel_y')
voxel_z = bdata.select('voxel_z')
sample = 0
voxels = np.column_stack((voxel_x, voxel_z))
plt.imshow(voxels.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()
